# %%
import pandas as pd

# %%
income_file_path = "./median_incomes.csv"
rent_file_path = "./median_rents.csv"

# Skip metadata lines and read the actual data
median_incomes = pd.read_csv(income_file_path, skiprows=6, names=["Neighborhood", "Household","Year", "Currency", "Median Income", "FIPS"])
median_rents = pd.read_csv(rent_file_path, skiprows=6, names=["Neighborhood", "Year", "Currency", "Median Rent", "FIPS"])

# %%
median_incomes
# Out:
#         Neighborhood                  Household  Year Currency Median Income  \
# 0          Riverdale             All Households  2005  Dollars   66429.87643
# 1     Williamsbridge             All Households  2005  Dollars   54603.07992
# 2        Throgs Neck             All Households  2005  Dollars   60436.77167
# 3     Pelham Parkway             All Households  2005  Dollars   55273.71398
# 4         Morrisania             All Households  2005  Dollars    25750.6987
# ...              ...                        ...   ...      ...           ...
# 4155        Brooklyn  Families without Children  2021  Dollars         78468
# 4156       Manhattan  Families without Children  2021  Dollars        103149
# 4157          Queens  Families without Children  2021  Dollars         85650
# 4158   Staten Island  Families without Children  2021  Dollars        104925
# 4159   New York City  Families without Children  2021  Dollars         81269
#
#          FIPS
# 0         208
# 1         212
# 2         210
# 3         211
# 4         203
# ...       ...
# 4155    36047
# 4156    36061
# 4157    36081
# 4158    36085
# 4159  3651000
#
# [4160 rows x 6 columns]

# %%
median_rents
# Out:
#         Neighborhood  Year Currency  Median Rent     FIPS
# 0          Riverdale  2005  Dollars   1102.14859      208
# 1     Williamsbridge  2005  Dollars   1067.79234      212
# 2        Throgs Neck  2005  Dollars   1003.20259      210
# 3     Pelham Parkway  2005  Dollars   1071.91509      211
# 4         Morrisania  2005  Dollars    770.95432      203
# ...              ...   ...      ...          ...      ...
# 1035        Brooklyn  2021  Dollars   1525.00000    36047
# 1036       Manhattan  2021  Dollars   1789.00000    36061
# 1037          Queens  2021  Dollars   1630.00000    36081
# 1038   Staten Island  2021  Dollars   1306.00000    36085
# 1039   New York City  2021  Dollars   1385.00000  3651000
#
# [1040 rows x 5 columns]

# %%
clean_incomes = median_incomes.loc[median_incomes["Household"].str.contains("All Households", case=False, na=False)]
clean_incomes = clean_incomes.drop(columns=["Household"])
clean_incomes = clean_incomes.drop(columns=["FIPS"])
clean_incomes = clean_incomes.drop(columns=["Currency"])

# %%
clean_rents = median_rents.drop(columns=["FIPS"])
clean_rents = clean_rents.drop(columns=["Currency"])

# %%
# Merge the two datasets on Neighborhood and Year to align income and rent data
merged_data = pd.merge(clean_rents, clean_incomes, on=["Neighborhood", "Year"], suffixes=("_Rent", "_Income"))

# Compute Rent-to-Income Ratio (RTI) as (Median Rent / Median Income) * 100
merged_data["RTI (%)"] = (merged_data["Median Rent"] / merged_data["Median Income"]) * 100

# %%
merged_data
# Out:
#         Neighborhood  Year  Median Rent  Estimated Median Income   RTI (%)  \
# 0          Riverdale  2005   1102.14859             65326.522333  1.659116
# 1     Williamsbridge  2005   1067.79234             65326.522333  1.955553
# 2        Throgs Neck  2005   1003.20259             65326.522333  1.659921
# 3     Pelham Parkway  2005   1071.91509             65326.522333  1.939285
# 4         Morrisania  2005    770.95432             65326.522333  2.993916
# ...              ...   ...          ...                      ...       ...
# 1035        Brooklyn  2021   1525.00000             65326.522333  2.257019
# 1036       Manhattan  2021   1789.00000             65326.522333  2.118790
# 1037          Queens  2021   1630.00000             65326.522333  2.224891
# 1038   Staten Island  2021   1306.00000             65326.522333  1.517652
# 1039   New York City  2021   1385.00000             65326.522333  2.036855
#
#       Median Income
# 0       66429.87643
# 1       54603.07992
# 2       60436.77167
# 3       55273.71398
# 4       25750.69870
# ...             ...
# 1035    67567.00000
# 1036    84435.00000
# 1037    73262.00000
# 1038    86054.00000
# 1039    67997.00000
#
# [1040 rows x 6 columns]
